# %% [markdown]
# <a href="https://colab.research.google.com/github/nupurradke5-pixel/Phython-Programming/blob/main/String_And_Conditional_Statement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str1 = "This is a string."
str2 = 'This is a string'
str3 = """This is a string"""
print(str1)
# Out:
# This is a string.

# %%
str3 = """This is a string.\n my name is nupur."""

print(str3)
# Out:
# This is a string.
#  my name is nupur.

# %%
str3 = """This is a string.\t my name is nupur."""

print(str3)
# Out:
# This is a string.	 my name is nupur.

# %%
#Concatenation(Sum)
str1 = "Nupur"
str2 = "Radke"
print(str1+str2)
# Out:
# NupurRadke

# %%
#length of Str
str1 = "Nupur"
len1 = len(str1)
print(len1)
str2 = "Radke"
len2 = len(str2)
print(len2)

finalstr = str1 + " " +  " " + str2
print(final_str)
print(len(final_str))
#in length space is also counted
# Out:
# 5
# 5
# Nupur Radke
# 11

# %%
str = "nupur radke"
ch = str[2]
print(ch)

str = "Heyyy"
print(str[0])

str = "Heyy_y"
print(str[4])
# Out:
# p
# H
# _

# %%
#Slicing(Accesing Parts of a string
str = "Nupur Radke"
print(str[1:8])

str = "Nupur_Radke"
print(str[5:len(str)])
# Out:
# upur Ra
# _Radke

# %%
#Negative Slicing (backward counting iss)
str = "nupur"
print(str[-2:-1])
# Out:
# u

# %%
#String Function
str = "I am studying python from Apnacollege"
print(str.endswith("ege"))

str = "i am studying python from Apnacollege"
print(str.capitalize())
print(str)

str = "I am studying python from Apnacollege"
print(str.replace("o", "G"))

str = "I am studying python from Apnacollege"
print(str.replace("Apnacollege", "X"))

str = "I am studying python from Apnacollege"
print(str.find("o"))

str = "I am studying python from Apnacollege"
print(str.find("x"))

str = "I am studying python from Apnacollege"
print(str.count("python"))
# Out:
# True
# I am studying python from apnacollege
# i am studying python from Apnacollege
# I am studying pythGn frGm ApnacGllege
# I am studying python from X
# 18
# -1
# 1

# %%
#write a program to input users 1st name and print its length
a = input("Enter your first name: ")
print(len(a))
# Out:
# Enter your first name: Nuppu
# 5

# %%
#WAP to find occurrence of '$ in a string
str = "Nupur$radke"
print(str.count("$"))
# Out:
# 1

# %%
 #Conditional Statement :
 light = "green"
if(light == "red"):
    print("stop")
elif(light == "green"):
    print("go")
elif(light == "yellow"):
    print("look")
 #if will check statement always but
 #elif will ony check whether if statemengive false

 num = 5

if(num > 2):
    print("greater than 2")
elif(num > 3):
    print("greater than 3")
# Out:
# go
# greater than 2
